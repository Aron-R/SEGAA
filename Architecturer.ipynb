# %%
import keras
import visualkeras
from keras.utils.vis_utils import plot_model

# %%
model_name = "pre-trained_models/Individual Models/gender_MLP_model"

# %%
model = keras.models.load_model(f"{model_name}.keras")

# %%
plot_model(model, to_file=f'{model_name}.png', show_shapes=True, show_layer_names=True)
